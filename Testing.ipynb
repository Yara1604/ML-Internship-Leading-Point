# %%
path = 'C:/Users/yarah/Projects/LeadingPoint/test.jpg' # Change backslash to forward to avoid errors
path2 = 'C:/Users/yarah/Projects/LeadingPoint/data.h.file.png'
path3 = 'C:/Users/yarah/Projects/LeadingPoint/data.h.file.yara.png'

result = path3.split('/')[-1].rsplit('.', 1)

print(f"filename: {path3.split('/')[-1].rsplit('.', 1)[0]} \nfile extension: {path3.split('/')[-1].rsplit('.', 1)[1]}")
# Out:
# filename: data.h.file.yara
# file extension: png

# %%
# Detection vs Recognition
# EDA
# Spam email
